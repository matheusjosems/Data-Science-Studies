# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fa686948-dc0a-4c23-a8b2-4be4a52a4e1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa686948-dc0a-4c23-a8b2-4be4a52a4e1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dfnotas=pd.read_csv('notas alunos.csv', sep=';')

# %%
print(dfnotas)
# Out:
#    Notas de Alunos Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0            Nomes    Nota 1      Nota 2     Nota 3     Nota 4      Média
# 1            Pedro          4          7          7          3        5,5
# 2           Carlos          5          4          8          4        4,5
# 3              Ana          6          5          4          5        5,0
# 4            Fabio          7          6          9          6        6,5
# 5         Patricia          8          6          5          7        6,5
# 6           Marcos          7          2          8          8        7,5
# 7           Samuel          9          3          7          2        5,0
# 8            Karol          7          3          5          1        4,0
# 9             Jose          8          6          2          2        4,0
# 10         Rodrigo          1          7          9          4        5,5

# %%
dfnotasarred=pd.read_csv('notas arredondadas.csv', sep=';')

# %%
print(dfnotasarred)
# Out:
#    Notas de Alunos Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0            Nomes    Nota 1      Nota 2     Nota 3     Nota 4      Média
# 1            Pedro          4          7          7          3          6
# 2           Carlos          5          4          8          4          5
# 3              Ana          6          5          4          5          5
# 4            Fabio          7          6          9          6          7
# 5         Patricia          8          6          5          7          7
# 6           Marcos          7          2          8          8          8
# 7           Samuel          9          3          7          2          5
# 8            Karol          7          3          5          1          4
# 9             Jose          8          6          2          2          4
# 10         Rodrigo          1          7          9          4          6

# %%
vendas = pd.DataFrame({
    'data': ['2026-02-01', '2026-02-02', '2026-02-03', '2026-02-04'],
    'produto': ['Notebook', 'Mouse', 'Teclado', 'Monitor'],
    'quantidade': [2, 15, 8, 3],
    'preco_unitario': [2500, 50, 180, 800],
    'categoria': ['Informática', 'Informática', 'Informática', 'Informática']})

# %%
print(vendas)
# Out:
#          data   produto  quantidade  preco_unitario    categoria
# 0  2026-02-01  Notebook           2            2500  Informática
# 1  2026-02-02     Mouse          15              50  Informática
# 2  2026-02-03   Teclado           8             180  Informática
# 3  2026-02-04   Monitor           3             800  Informática

# %%
vendas
# Out:
#          data   produto  quantidade  preco_unitario    categoria
# 0  2026-02-01  Notebook           2            2500  Informática
# 1  2026-02-02     Mouse          15              50  Informática
# 2  2026-02-03   Teclado           8             180  Informática
# 3  2026-02-04   Monitor           3             800  Informática

# %%
vendas.shape
# Out:
# (4, 5)

# %%
vendas.columns
# Out:
# Index(['data', 'produto', 'quantidade', 'preco_unitario', 'categoria'], dtype='object')

# %%
vendas.dtypes
# Out:
# data              object
# produto           object
# quantidade         int64
# preco_unitario     int64
# categoria         object
# dtype: object

# %%
print (vendas['quantidade'].dtype)
# Out:
# int64

# %%
vendas ['quantidade'] = vendas ['quantidade'].astype('int32')

# %%
print (vendas['quantidade'].dtype)
# Out:
# int32

# %%
vendas ['quantidade'] = vendas ['quantidade'].astype('float32')

# %%
print (vendas['quantidade'].dtype)
# Out:
# float32

# %%
vendas ['preco_unitario'].mean()
# Out:
# np.float64(882.5)

# %%
vendas.describe()
# Out:
#        quantidade  preco_unitario
# count    4.000000        4.000000
# mean     7.000000      882.500000
# std      5.944185     1126.894701
# min      2.000000       50.000000
# 25%      2.750000      147.500000
# 50%      5.500000      490.000000
# 75%      9.750000     1225.000000
# max     15.000000     2500.000000
